# %%
import json
import pandas as pd

with open('./data/data.json', 'r') as f:
    data = json.load(f)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data
# Out:
# {'질병': ['1형 양극성장애',
#   '2형 양극성장애',
#   'A형간염',
#   'B형간염',
#   'C형간염',
#   '가성점액종',
#   '각막혼탁 및 반흔',
#   '간경화증',
#   '간내 담도암',
#   '간농양',
#   '간모세포종',
#   '간암',
#   '간염',
#   '간의 양성종양',
#   '간의 양성종양(간낭종)',
#   '간의 양성종양(간선종)',
#   '간의 양성종양(간혈관종)',
#   '간의 양성종양(국소성 결절 과형성...',
#   '간의 양성종양(담관낭선종)',
#   '간흡충증',
#   '갈색세포종',
#   '감기',
#   '감염단핵구증',
#   '감염성심내막염',
#   '갑상선 결절',
#   '갑상선 양성 종양',
#   '갑상선기능저하증',
#   '갑상선기능항진증',
#   '갑상선암',
#   '갑상선염',
#   '강박장애',
#   '강직성척추염',
#   '거식증',
#   '건막염',
#   '건막염(감염성 건막염)',
#   '건막염(류마치스 건막염)',
#   '건막염(통풍성 건막염)',
#   '건막염(특발성 건막염)',
#   '건선',
#   '결장암',
#   '결핵',
#   '경계성 성격장애',
#   '경도 인지장애',
#   '고칼슘혈증',
#   '고혈압',
#   '고혈압과 눈(고혈압망막병증)',
#   '고혈압성 심질환',
#   '고혈압성 콩팥병',
#   '고환암',
#   '골감소증',
#   '골관절염',
#   '골수염',
#   '골수이형성증후군',
#   '골절',
#   '공수병(광견병)',
#   '공황장애',
#   '과민성장증후군',
#   '광동주혈선충증',
#   '교모세포종',
#   '구강건조증',
#   '구강암',
#   '구개열',
#   '구내염',
#   '구순암',
#   '구인두-편도암(HPV 관련)',
#   '구인두-하인두암(HPV 비관련)',
#   '굳은살과 티눈',
# ...

# %%
df1 = pd.DataFrame(data['질병'])
df1
# Out:
#                          0
# 0                 1형 양극성장애
# 1                 2형 양극성장애
# 2                     A형간염
# 3                     B형간염
# 4                     C형간염
# ..                     ...
# 556                    후두암
# 557             후천성면역결핍증후군
# 558  흉곽기형(오목가슴, 함몰흉, 누두...
# 559                흉막염과 농흉
# 560                    흉선암
#
# [561 rows x 1 columns]

# %%
df2 = pd.DataFrame(data['건강'])
df2
# Out:
#                          0
# 0                     가려움증
# 1                가정 내 아동안전
# 2                       객혈
# 3              거부반응과 면역억제제
# 4                    경부 종괴
# ..                     ...
# 98   해외여행 시 주의해야 할 감염병!...
# 99                      황달
# 100                     흉통
# 101                     황달
# 102                     흉통
#
# [103 rows x 1 columns]

# %%
lst1 = df1[0].to_list()

# %%
lst2 = df2[0].to_list()

# %%
len(set(lst1))
# Out:
# 528

# %%
lst = lst1 + lst2

# %%
with open('./data/data_dis.json', 'r') as f:
    detail_data =  json.load(f)

# %%
len(detail_data['질병'])
# Out:
# 561

# %%
detail_data
# Out:
# {'질병': ['1형 양극성장애',
#   '2형 양극성장애',
#   'A형간염',
#   'B형간염',
#   'C형간염',
#   '가성점액종',
#   '각막혼탁 및 반흔',
#   '간경화증',
#   '간내 담도암',
#   '간농양',
#   '간모세포종',
#   '간암',
#   '간염',
#   '간의 양성종양',
#   '간의 양성종양(간낭종)',
#   '간의 양성종양(간선종)',
#   '간의 양성종양(간혈관종)',
#   '간의 양성종양(국소성 결절 과형성...',
#   '간의 양성종양(담관낭선종)',
#   '간흡충증',
#   '갈색세포종',
#   '감기',
#   '감염단핵구증',
#   '감염성심내막염',
#   '갑상선 결절',
#   '갑상선 양성 종양',
#   '갑상선기능저하증',
#   '갑상선기능항진증',
#   '갑상선암',
#   '갑상선염',
#   '강박장애',
#   '강직성척추염',
#   '거식증',
#   '건막염',
#   '건막염(감염성 건막염)',
#   '건막염(류마치스 건막염)',
#   '건막염(통풍성 건막염)',
#   '건막염(특발성 건막염)',
#   '건선',
#   '결장암',
#   '결핵',
#   '경계성 성격장애',
#   '경도 인지장애',
#   '고칼슘혈증',
#   '고혈압',
#   '고혈압과 눈(고혈압망막병증)',
#   '고혈압성 심질환',
#   '고혈압성 콩팥병',
#   '고환암',
#   '골감소증',
#   '골관절염',
#   '골수염',
#   '골수이형성증후군',
#   '골절',
#   '공수병(광견병)',
#   '공황장애',
#   '과민성장증후군',
#   '광동주혈선충증',
#   '교모세포종',
#   '구강건조증',
#   '구강암',
#   '구개열',
#   '구내염',
#   '구순암',
#   '구인두-편도암(HPV 관련)',
#   '구인두-하인두암(HPV 비관련)',
#   '굳은살과 티눈',
# ...

# %%
with open('./data/data_health.json', 'r') as f:
    detail_data2 =  json.load(f)
detail_data2['건강'][0]
# Out:
# '가려움증'

# %%
with open('./data/data_anatomy.json', 'r') as f:
    detail_data3 =  json.load(f)

# %%
len(detail_data3)
# Out:
# 21

# %%
detail_data3['가슴']
# Out:
# [[{'갈비뼈(Rib)': ['다른질환보기\n갈비뼈(Rib)\n부위\n가슴\n질환\n근골격질환\n설명\n관련질환\n정의\n흉추와 복장뼈를 연결하여 가슴 전체를 둘러싸고 있는 가슴우리(흉강)을 형성하는 긴 곡선의 뼈를 말합니다. 갈비뼈는 폐, 심장 등 내부 가슴 장기들을 보호하고 가슴우리의 팽창과 수축으로 호흡을 도와줍니다. \n위치\n흉추와 복장뼈를 연결하여 가슴 전체를 둘러싸고 있으며 가슴우리(흉강)을 형성합니다. \n구조\n우리 몸은 총 12쌍의 갈비뼈를 가지고 있습니다. 1~7번 갈비뼈는 복장뼈와 직접 관절로 연결되어 있어 참갈비뼈라고 하고, 8~12번 갈비뼈는 거짓 갈비뼈라고 하는데 거짓 갈비뼈 중 8,9,10번 갈비뼈는 하나의 연골을 통해 복장뼈와 연결되어 있고 나머지 11~12번째 갈비뼈는 뜬갈비뼈로 복장뼈와 연결되어 있지 않습니다. \n기능\n폐, 심장 등 내부 가슴 장기들을 보호하고 가슴우리의 팽창과 수축으로 호흡을 도와줍니다. \n헬스팁\n▶정상적으로 우리가 숨을 들이마실 때 횡격막은 수축하고 가슴우리는 팽창하여 폐 안으로 공기가 들어오게 되며, 숨을 내쉴때는 횡격막은 이완하고 가슴우리는 수축하여 폐 안의 공기는 밖으로 배출되게 됩니다. \n▶갈비뼈는 외부 충격이 가해지거나 순간적으로 과도하게 힘이 들어갈 경우 부러지거나 금이 갈 수 있습니다. 갈비뼈에 금이 가거나 골절 되었을 경우 별도의 수술은 필요하지 않고 갈비뼈에 충격이 가지 않도록 보호장구를 착용하여 뼈가 아물도록 기다립니다. 하지만 갈비뼈 골절로 인해 갈비뼈가 보호하고 있는 내부장기가 손상을 받아 출혈이 되거나 폐에서 공기가 새어 나와 기흉이 생기는 등 합병증이 발생하면 위험할 수 있습니다.'],
# ...

# %%
detail_data3['가슴'][0]
# Out:
# [{'갈비뼈(Rib)': ['다른질환보기\n갈비뼈(Rib)\n부위\n가슴\n질환\n근골격질환\n설명\n관련질환\n정의\n흉추와 복장뼈를 연결하여 가슴 전체를 둘러싸고 있는 가슴우리(흉강)을 형성하는 긴 곡선의 뼈를 말합니다. 갈비뼈는 폐, 심장 등 내부 가슴 장기들을 보호하고 가슴우리의 팽창과 수축으로 호흡을 도와줍니다. \n위치\n흉추와 복장뼈를 연결하여 가슴 전체를 둘러싸고 있으며 가슴우리(흉강)을 형성합니다. \n구조\n우리 몸은 총 12쌍의 갈비뼈를 가지고 있습니다. 1~7번 갈비뼈는 복장뼈와 직접 관절로 연결되어 있어 참갈비뼈라고 하고, 8~12번 갈비뼈는 거짓 갈비뼈라고 하는데 거짓 갈비뼈 중 8,9,10번 갈비뼈는 하나의 연골을 통해 복장뼈와 연결되어 있고 나머지 11~12번째 갈비뼈는 뜬갈비뼈로 복장뼈와 연결되어 있지 않습니다. \n기능\n폐, 심장 등 내부 가슴 장기들을 보호하고 가슴우리의 팽창과 수축으로 호흡을 도와줍니다. \n헬스팁\n▶정상적으로 우리가 숨을 들이마실 때 횡격막은 수축하고 가슴우리는 팽창하여 폐 안으로 공기가 들어오게 되며, 숨을 내쉴때는 횡격막은 이완하고 가슴우리는 수축하여 폐 안의 공기는 밖으로 배출되게 됩니다. \n▶갈비뼈는 외부 충격이 가해지거나 순간적으로 과도하게 힘이 들어갈 경우 부러지거나 금이 갈 수 있습니다. 갈비뼈에 금이 가거나 골절 되었을 경우 별도의 수술은 필요하지 않고 갈비뼈에 충격이 가지 않도록 보호장구를 착용하여 뼈가 아물도록 기다립니다. 하지만 갈비뼈 골절로 인해 갈비뼈가 보호하고 있는 내부장기가 손상을 받아 출혈이 되거나 폐에서 공기가 새어 나와 기흉이 생기는 등 합병증이 발생하면 위험할 수 있습니다.'],
# ...
